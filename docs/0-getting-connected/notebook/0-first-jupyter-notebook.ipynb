# %% [markdown]
# # Getting Connected
#
# Welcome to your first Jupyter notebook in OpenShift AI!
#
# This notebook will help you get familiar with running code cells, viewing output, and exploring your environment.

# %% [markdown]
# ## 1. Running a code cell
#
# Click on the cell below and press **Shift+Enter** to run it.

# %%
print("Hello from OpenShift AI!")

# %% [markdown]
# ## 2. Variables and expressions
#
# You can store values in variables and use them across cells.

# %%
name = "AI Roadshow"
year = 2026
print(f"Welcome to {name} {year}!")

# %% [markdown]
# ## 3. Check your Python version

# %%
import sys
print(f"Python version: {sys.version}")

# %% [markdown]
# ## 4. Check for GPU
#
# Let's verify that a GPU is available in this workbench.

# %%
import torch

if torch.cuda.is_available():
    print(f"GPU available: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")
else:
    print("No GPU detected - running on CPU only")

# %% [markdown]
# ## 5. Working with lists and loops
#
# A simple example to practice running cells.

# %%
toppings = ["pepperoni", "mushrooms", "olives", "basil", "mozzarella"]

for i, topping in enumerate(toppings, 1):
    print(f"{i}. {topping}")

print(f"\nTotal toppings: {len(toppings)}")

# %% [markdown]
# ## 6. Writing a function
#
# Try creating your own function.

# %%
def pizza_order(size, toppings):
    base_price = {"small": 8, "medium": 12, "large": 16}
    price = base_price.get(size, 12) + len(toppings) * 1.5
    return f"{size.title()} pizza with {', '.join(toppings)} - ${price:.2f}"

print(pizza_order("large", ["pepperoni", "mushrooms", "olives"]))
print(pizza_order("small", ["mozzarella"]))

# %% [markdown]
# ## Try it yourself!
#
# Add a new cell below (click **+** in the toolbar or press **B**) and experiment:
# - Create your own variables
# - Write a function
# - Import a library and explore it
#
# There is no risk of breaking anything - this is your environment!
